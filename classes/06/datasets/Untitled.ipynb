# %%
import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-06-storms.csv.gz'))

# %%
df.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# BGN_AZI       547332
# BGN_LOCATI    287743
# END_DATE      243411
# END_TIME      238978
# COUNTY_END         0
# COUNTYENDN    902297
# END_RANGE          0
# END_AZI       724837
# END_LOCATI    499225
# LENGTH             0
# WIDTH              0
# F             843563
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# PROPDMGEXP    465934
# CROPDMG            0
# CROPDMGEXP    618413
# WFO           142069
# STATEOFFIC    248769
# ZONENAMES     594029
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REMARKS       287433
# REFNUM             0
# dtype: int64

# %%
df_temp = df[['EVTYPE','BGN_DATE','BGN_TIME', 'FATALITIES', 'INJURIES', 'PROPDMG', 'CROPDMG', 'PROPDMGEXP', 'CROPDMGEXP']]

# %%
df_temp.groupby(by=['EVTYPE'])['FATALITIES','INJURIES'].sum()
# Out:
#                              FATALITIES  INJURIES
# EVTYPE
#    HIGH SURF ADVISORY               0.0       0.0
#  COASTAL FLOOD                      0.0       0.0
#  FLASH FLOOD                        0.0       0.0
#  LIGHTNING                          0.0       0.0
#  TSTM WIND                          0.0       0.0
#  TSTM WIND (G45)                    0.0       0.0
#  WATERSPOUT                         0.0       0.0
#  WIND                               0.0       0.0
# ?                                   0.0       0.0
# ABNORMAL WARMTH                     0.0       0.0
# ABNORMALLY DRY                      0.0       0.0
# ABNORMALLY WET                      0.0       0.0
# ACCUMULATED SNOWFALL                0.0       0.0
# AGRICULTURAL FREEZE                 0.0       0.0
# APACHE COUNTY                       0.0       0.0
# ASTRONOMICAL HIGH TIDE              0.0       0.0
# ASTRONOMICAL LOW TIDE               0.0       0.0
# AVALANCE                            1.0       0.0
# ...

# %%
df_clean[(df_temp['FATALITIES'] != 0) & (df_temp['INJURIES'] != 0)]
# Out:
# /Users/eunicelau/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                    EVTYPE            BGN_DATE     BGN_TIME  FATALITIES  \
# 8                 TORNADO   2/13/1952 0:00:00         2000         1.0
# 12                TORNADO   2/13/1952 0:00:00         2130         1.0
# 15                TORNADO   3/22/1952 0:00:00         1500         4.0
# 25                TORNADO   2/20/1953 0:00:00         1610         1.0
# 33                TORNADO   4/18/1953 0:00:00         1700         6.0
# 35                TORNADO    5/1/1953 0:00:00         1930         7.0
# 37                TORNADO    5/1/1953 0:00:00         2000         2.0
# 69                TORNADO   4/24/1955 0:00:00          545         5.0
# 93                TORNADO   4/15/1956 0:00:00         1500        25.0
# 121               TORNADO    4/8/1957 0:00:00         1015         2.0
# ...

# %%
df_clean.groupby(by=['EVTYPE'])['FATALITIES','INJURIES'].sum()
# Out:
#                            FATALITIES  INJURIES
# EVTYPE
# AVALANCHE                        52.0      79.0
# BLACK ICE                         1.0      24.0
# BLIZZARD                         48.0     718.0
# BLOWING SNOW                      1.0      13.0
# COASTAL STORM                     1.0       1.0
# COLD                              8.0      48.0
# COLD/WIND CHILL                   3.0       2.0
# DENSE FOG                        14.0     157.0
# DUST STORM                       19.0     106.0
# EXCESSIVE HEAT                  402.0    4791.0
# EXCESSIVE RAINFALL                2.0      21.0
# EXTREME COLD                     25.0     199.0
# EXTREME COLD/WIND CHILL          12.0      15.0
# EXTREME WINDCHILL                 2.0       2.0
# FLASH FLOOD                     171.0     641.0
# FLOOD                           104.0    2679.0
# FLOOD/FLASH FLOOD                 3.0       5.0
# FLOODING                          2.0       1.0
# ...

# %%
# Out:
# /Users/eunicelau/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#                    EVTYPE            BGN_DATE     BGN_TIME  FATALITIES  \
# 8                 TORNADO   2/13/1952 0:00:00         2000         1.0
# 12                TORNADO   2/13/1952 0:00:00         2130         1.0
# 15                TORNADO   3/22/1952 0:00:00         1500         4.0
# 25                TORNADO   2/20/1953 0:00:00         1610         1.0
# 33                TORNADO   4/18/1953 0:00:00         1700         6.0
# 35                TORNADO    5/1/1953 0:00:00         1930         7.0
# 37                TORNADO    5/1/1953 0:00:00         2000         2.0
# 69                TORNADO   4/24/1955 0:00:00          545         5.0
# 93                TORNADO   4/15/1956 0:00:00         1500        25.0
# 121               TORNADO    4/8/1957 0:00:00         1015         2.0
# ...
